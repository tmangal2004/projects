# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df=pd.read_csv('/content/archive (8).zip')
# df
df=pd.read_csv('/content/archive (8).zip')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
# Distribution of age
sns.histplot(df['age'],color='blue', bins=20)  #helps to visulasize dataset distributions
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Distribution of cholesterol levels
sns.histplot(df['chol'], color='green', bins=20)
plt.title('Cholesterol Distribution')
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
plt.show()

# %%
# # Calculate the correlation matrix
# corr_matrix = df.corr()

# # corr() finds the correlation between every column(variable) in the dataframe with one another
# # Plot the heatmap
# # plt.figure(figsize=(10, 8))
# sns.heatmap(corr_matrix,annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# plt.title('Correlation Matrix')
# plt.show()
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Count plot for heart disease by gender
sns.countplot(data=df, x='sex', hue='target')
plt.title('Heart Disease Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Count plot for heart disease by chest pain type
sns.countplot(data=df, x='cp', hue='target')
plt.title('Heart Disease Distribution by Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
# Inefficient - Creates a copy
df = df[df['age'] > 40].copy()

# Efficient - No copy made
df = df[df['age'] > 40]
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
# # Data Cleaning: Drop rows with missing values
# df = df.dropna()

# # Descriptive statistics
# print(df.describe())

# # Plot distributions
# sns.histplot(df['age'], kde=True, color='blue', bins=20)
# plt.title('Age Distribution')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.show()

# # Correlation heatmap
# corr_matrix = df.corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# plt.title('Correlation Matrix')
# plt.show()

# # Distribution of heart disease by gender
# sns.countplot(data=df, x='sex', hue='target')
# plt.title('Heart Disease Distribution by Gender')
# plt.xlabel('Gender')
# plt.ylabel('Count')
# plt.show()

# # Efficient feature engineering example
# df['chol_level'] = np.where(df['chol'] > 240, 'High', 'Normal')
# print(df['chol_level'].value_counts())

# # Create an age group
# df['age_group'] = pd.cut(df['age'], bins=[29, 39, 49, 59, 69, 100], labels=['30-39', '40-49', '50-59', '60-69', '70+'])
# print(df['age_group'].value_counts())

# %%
sns.boxplot(x='target', y='chol', data=df)
plt.show()

# %%
f_sorted = df.sort_values(by='chol', ascending=False)
f_sorted
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 158   67    0   2       115   564    0        0      160      0      1.6
# 192   67    0   2       115   564    0        0      160      0      1.6
# 464   67    0   2       115   564    0        0      160      0      1.6
# 665   65    0   2       140   417    1        0      157      0      0.8
# 958   65    0   2       140   417    1        0      157      0      0.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 32    57    1   0       130   131    0        1      115      1      1.2
# 925   57    1   0       130   131    0        1      115      1      1.2
# 475   57    1   2       150   126    1        1      173      0      0.2
# 101   57    1   2       150   126    1        1      173      0      0.2
# 336   57    1   2       150   126    1        1      173      0      0.2
#
#      slope  ca  thal  target
# 158      1   0     3       1
# 192      1   0     3       1
# ...

# %%
age_sorted=df.sort_values(by='age',ascending=False)
age_sorted
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 387   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 160   77    1   0       125   304    0        0      162      1      0.0
# 965   76    0   2       140   197    0        2      116      0      1.1
# 99    76    0   2       140   197    0        2      116      0      1.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 779   34    0   1       118   210    0        1      192      0      0.7
# 668   29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
#
#      slope  ca  thal  target
# 387      2   3     2       0
# 162      2   3     2       0
# ...
